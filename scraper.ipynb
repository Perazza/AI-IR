# %%
import PyPDF2
from openai import OpenAI
from dotenv import load_dotenv
import os
import requests
import json

# %%
#Using dotEnv to call apiKey from openAI
load_dotenv()

apikey = os.getenv('APIKey')

# %%
def extract_text_from_pdf(pdf_file_path):
    text = ''
    with open(pdf_file_path, 'rb') as file:
        reader = PyPDF2.PdfReader(file)
        num_pages = len(reader.pages)
        for page_num in range(num_pages):
            page = reader.pages[page_num]
            text += page.extract_text()
    return text

# %%
pdf_file_path = 'ri\Release de Resultados 3T23 tupy.pdf'
pdf_text = extract_text_from_pdf(pdf_file_path)

# %%
pdf_text
# Out:
# '0.      \n \n \n \n \n \n                                        \n      \n \nForte geração de caixa operacional , \ncaptura de sinergias e crescimento  \ndas margens  \n \n▪ Receit as: R$ 3,0 bilhões no 3T23 (+10% vs 3T22), incluindo resultado \nproveniente da MWM Tupy do Brasil (“MWM”), no valor de, \naproximadamente, R$ 597 milhões. Impacto da apreciação do Real vs \nDólar (+ 7%), sendo 68% das receitas da Companhia no período em \nmoeda estrangeira . Efeito também  da queda da produção de veículos \npesados no Brasi l, decorrente d a mudança de tecnologia de emissões de \nmotores (Proconve P8 / Euro 6) e desempenho de indicadores \neconômicos , resultando em vendas inferiores às do mesmo período em \n2022 ( -7% no volume físico de componentes  estruturais ). \n▪ Fluxo de caixa operacional: geração de R$ 359 milhões no 3T23,  aumento \nde 56% na comparação com o 3T2 2, decorrente  de ganhos de eficiência e  \niniciativas de  redução  de capital de giro .  \n▪ EBITDA Ajustado de R
# ...

# %%
header = {'Authorization': f'Bearer {apikey}', 'Content-Type': 'application/json'}
link = 'https://api.openai.com/v1/chat/completions'
idModel = "gpt-3.5-turbo"

body = {
    "model": idModel,
    "messages": [{'role':'user', 'content': 'Ola tudo bem?'}]
}

bodyM = json.dumps(body)

request = requests.post(link, headers=header, data=bodyM)
print(request.text)
# Out:
# {
#     "error": {
#         "message": "You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.",
#         "type": "insufficient_quota",
#         "param": null,
#         "code": "insufficient_quota"
#     }
# }
